# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
data = pd.read_excel("./datasets/복합기 크롤링 중복제거.xlsx")
#data = data.rename(columns = {"스펙 목록":"제품 구분","Unnamed:3":"인쇄/출력 방식","Unnamed:4":""})
data1 = data
data1.head()
# Out:
#                상품명       가격        스펙 목록 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   ApeosPort 2560  2125000  흑백 디지털 복합기        잉크젯      포토프린터      컬러 출력
# 1   ApeosPort 3060  2200000  흑백 디지털 복합기        잉크젯      포토프린터      컬러 출력
# 2   ApeosPort 3560  2528000  흑백 디지털 복합기        잉크젯      컬러 출력         복사
# 3  ApeosPort C2060  2600000  컬러 디지털 복합기         인쇄         복사         스캔
# 4  ApeosPort C2560  2778170  컬러 디지털 복합기         인쇄         복사         스캔
#
#        Unnamed: 6          Unnamed: 7              Unnamed: 8  \
# 0             복사                  스캔                      팩스
# 1             복사                  스캔                      팩스
# 2             스캔    인쇄 해상도: 4,800dpi                  무한 패키지
# 3   컬러 속도: 23ppm        흑백 속도: 28ppm    인쇄 해상도: 600 x 600dpi
# 4             팩스        컬러 속도: 23ppm            흑백 속도: 25ppm
#
#                  Unnamed: 9  ...  Unnamed: 20  Unnamed: 21  Unnamed: 22  \
# 0         인쇄 해상도: 4,800dpi   ...          NaN          NaN          NaN
# ...

# %%
item_user_table = pd.DataFrame(data=np.random.randint(0,2,size=(5901,30)), index=data['상품명'], columns=['user: ' + str(i) for i in range(0,30)])
item_user_table
# Out:
#                          user: 0  user: 1  user: 2  user: 3  user: 4  user: 5  \
# 상품명
# ApeosPort 2560                 0        1        1        0        0        1
# ApeosPort 3060                 0        1        0        0        1        1
# ApeosPort 3560                 1        1        0        0        0        1
# ApeosPort C2060                0        1        1        0        1        0
# ApeosPort C2560                0        1        0        0        0        0
# ...                          ...      ...      ...      ...      ...      ...
# 코니카미놀타 bizhub C451             1        1        0        0        0        1
# 코니카미놀타 C022DN                  1        1        0        1        0        0
# 코니카미놀타 C028DN                  0        1        1        1        1        0
# 코니카미놀타 C036DN                  1        1        1        1        1        1
# 코니카미놀타 MagiColor 4690MF        0        0        1        0        1        1
#
# ...

# %%
printer_sim = cosine_similarity(item_user_table,item_user_table)
printer_sim_df = pd.DataFrame(data=printer_sim,index=item_user_table.index,columns=item_user_table.index)
printer_sim_df
# Out:
# 상품명                      ApeosPort 2560  ApeosPort 3060  ApeosPort 3560  \
# 상품명
# ApeosPort 2560                 1.000000        0.400892        0.566947
# ApeosPort 3060                 0.400892        1.000000        0.589256
# ApeosPort 3560                 0.566947        0.589256        1.000000
# ApeosPort C2060                0.518563        0.666973        0.514496
# ApeosPort C2560                0.428571        0.534522        0.566947
# ...                                 ...             ...             ...
# 코니카미놀타 bizhub C451             0.500000        0.467707        0.629941
# 코니카미놀타 C022DN                  0.552052        0.580948        0.608581
# 코니카미놀타 C028DN                  0.490511        0.630893        0.648886
# 코니카미놀타 C036DN                  0.429198        0.630893        0.648886
# 코니카미놀타 MagiColor 4690MF        0.571429        0.534522        0.566947
#
# 상품명                      ApeosPort C2060  ApeosPort C2560  ApeosPort C3060  \
# 상품명
# ...

# %%
printer_sim_df['ApeosPort C2560'].sort_values(ascending=False)[1:200]
# Out:
# 상품명
# 삼성전자 MultiXpress SL-X4225RX    0.848668
# HP 11501C                      0.801784
# 삼성전자 SL-P7400LX                0.801784
# Brother MFC-L6900DW            0.797081
# 삼성전자 CLX-9252NA                0.797081
#                                  ...
# Lexmark CX510de 병행수입           0.668153
# HP 포토스마트 C309A 무한공급기           0.668153
# Canon PIXMA MP258 무한공급기        0.668153
# HP 포토스마트 C309A 무한공급기           0.668153
# HP 오피스젯 프로 8710                0.668153
# Name: ApeosPort C2560, Length: 199, dtype: float64
